# %% [markdown]
# <a href="https://colab.research.google.com/github/zeinafarghaly-arch/ML-flyrank/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > [Keep it simple. A good frame is one page. If you fill all four blanks and run top-to-bottom without errors, you're done.]

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I chose Refresh / Content Opportunity Scoring because the first notebook showed that search volume alone has almost no correlation with page impressions (0.001), suggesting that prioritizing pages requires combining multiple signals rather than relying on a single metric. I want to explore how machine learning can rank pages that should be refreshed, expanded, protected, pruned, or monitored to support content teams.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
My work aims to improve the decision of which pages should be reviewed first for content refresh. The recommendations would be used by content teams to decide whether a page should be refreshed, expanded, protected, pruned, or monitored. If the recommendations are wrong, the team may spend time on pages that do not need attention while missing pages that actually require updates, resulting in wasted effort and missed opportunities to improve website performance.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess
import pandas as pd

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

print("Working dir:", os.getcwd())

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Pages:", len(df))
print("Correlation:", df["search_volume"].corr(df["impressions_90d"]))
print(df["trend_direction"].value_counts())

#The dataset contains 30,000 pages, which gives plenty of data to explore. I also found that the correlation between search volume and impressions is only 0.001, showing that one metric alone is not enough to decide which pages need attention. Since pages have different performance trends, I think this is a good problem for building a smarter page-ranking system instead of relying on simple rules.
# Out:
# Working dir: /content/flyrank-ml-internship-starter
# Pages: 30000
# Correlation: 0.0012030310696208905
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, prediction, objectivity).*

# %%
This project looks for patterns in the data to suggest which pages may need attention. It supports decisions, but it cannot prove what causes ranking changes or promise better results after a page is updated.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom without errors
# - [ ] The numbers are real (loaded from the actual CSV)
# - [ ] I can explain each claim to someone in 1 minute
